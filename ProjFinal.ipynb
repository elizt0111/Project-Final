# %% [markdown]
# # Final Project: Milestone 2
# ### Elizabeth Trunk, CMP 262
# ### April 15, 2026

# %% [markdown]
# In this project, I will analyze waterfalls in New Jersey.

# %% [markdown]
# ### Set Up

# %%
import pandas as pd

# %%
df = "waterfalls.csv"
wf = pd.read_csv(df)

# %% [markdown]
# ### Initial Exploratory Analysis

# %%
wf
# Out:
#      OBJECTID   ID                        Waterfall Name Alternate Name  \
# 0           1   27                       Allamuchy Falls            NaN
# 1           2  109                         Apshawa Falls            NaN
# 2           3  118          Bear Swamp Brook Falls Lower            NaN
# 3           4  117          Bear Swamp Brook Falls Upper            NaN
# 4           5  108        Bear Swamp Brook Unnamed Falls            NaN
# ..        ...  ...                                   ...            ...
# 113       114   99  Van Campens Glen Unnamed Waterfall 2            NaN
# 114       115   24                   Wanaque River Falls            NaN
# 115       116   98                   Weldon Quarry Falls            NaN
# 116       117  100                        Wetumpka Falls            NaN
# 117       118   25                        Wyanokie Falls            NaN
#
#              Municipality   County      Waterfall Type 1 Waterfall Type 2  \
# 0              Byram Twp.   Sussex               Cascade
# 1       West Milford Twp.  Passaic               Cascade
# 2             Mahwah Twp.   Bergen               Cascade
# 3             Mahwah Twp.   Bergen               Cascade
# 4             Mahwah Twp.   Bergen               Cascade
# ..                    ...      ...                   ...              ...
# 113         Hardwick Twp.   Warren                Plunge
# 114     West Milford Twp.  Passaic                 Chute
# 115     Hopatcong Borough   Sussex               Cascade
# 116      Watchung Borough    Union               Cascade
# 117  Bloomingdale Borough  Passaic  Multi-step waterfall          Cascade
#
#      Approximate Height (ft)  Approximate Height 2 (ft)   Access  \
# 0                       9.68                       7.00   Public
# 1                       8.50                       8.50   Public
# 2                      15.00                      15.00   Public
# 3                      12.00                      12.00   Public
# 4                       5.30                       5.30   Public
# ..                       ...                        ...      ...
# 113                    11.00                      11.00   Public
# 114                     7.15                       7.15   Public
# 115                    10.20                       4.00  Private
# 116                    20.00                       9.00   Public
# 117                    31.50                      15.00   Public
#
#                                               Comments          Measurement  \
# 0    Located in Allamuchy Mountain State Park, this...  Trimble rangefinder
# 1    Located in Apshawa Preserve on Apshawa Creek. ...             Estimate
# 2    This falls slides over a big rounded ledge of ...    Literature search
# 3    The falls are up Bear Swamp Road, a private ro...    Literature search
# 4    The falls are up Bear Swamp Road, a private ro...  Trimble rangefinder
# ..                                                 ...                  ...
# 113  A small waterfall a few hundred feet upstream ...  Trimble rangefinder
# 114  Small waterfall located on the Wanaque River a...  Trimble rangefinder
# 115  A small cascade next to the Weldon Quarry on p...  Trimble rangefinder
# 116  Located along Somers Ave. on Stony Brook acros...  Trimble rangefinder
# 117  Two tier falls located along Blue Mine Brook. ...  Trimble rangefinder
#
#               Date Measured               Stream Name  NJSPC83 Easting (X)  \
# 0      5/9/2019 12:00:00 AM  Jefferson Lake Tributary           426335.368
# 1     5/24/2023 12:00:00 AM             Apshawa Creek           524366.923
# 2     5/25/2023 12:00:00 AM          Bear Swamp Brook           569200.226
# 3     5/25/2023 12:00:00 AM          Bear Swamp Brook           568961.724
# 4     5/25/2023 12:00:00 AM          Bear Swamp Brook           569465.790
# ..                      ...                       ...                  ...
# 113   6/25/2019 12:00:00 AM          Vancampens Brook           357357.892
# 114   4/14/2022 12:00:00 AM             Wanaque River           542914.892
# 115  11/20/2019 12:00:00 AM    Weldon Brook Tributary           458973.640
# 116   9/13/2017 12:00:00 AM               Stony Brook           506789.027
# 117   9/13/2017 12:00:00 AM           Blue Mine Brook           541848.548
#
#      NJSPC83 Northing (Y)                              GlobalID  \
# 0              764606.933  bbbf0c68-16aa-4d81-8db9-976f1e3e905c
# 1              796009.519  f469f397-9cfc-4148-a768-f0ec8fc2cc12
# 2              817439.079  c49b73cb-3293-453f-88c3-b04da0ff5698
# 3              817709.178  7b7f8a6a-fea4-40c0-91b5-bf6a5560d1c4
# 4              817181.169  86b3ee23-1f31-4d85-a28e-2ba6e3b12f62
# ..                    ...                                   ...
# 113            812291.224  6add5441-80d1-4048-b009-d0d87a08b9e8
# 114            848610.479  03221fce-47bc-45f5-95fc-8bae87889a9c
# 115            785094.430  2d124c38-199e-4529-adbe-3d46d8e5516e
# 116            655884.180  7c7b98ee-1455-4854-b30d-6aa1c215393c
# 117            812984.077  a2078aa6-ee1d-4972-8baf-b6fdc317ae6a
#
#                  x              y
# 0    426335.367977  764606.932952
# 1    524366.922898  796009.519097
# 2    569200.225948  817439.078928
# 3    568961.724128  817709.178125
# 4    569465.790049  817181.169011
# ..             ...            ...
# 113  357357.892087  812291.224066
# 114  542914.892035  848610.478855
# 115  458973.639971  785094.430035
# 116  506789.026951  655884.179925
# 117  541848.548039  812984.077011
#
# [118 rows x 20 columns]

# %%
wf.describe()
# Out:
#          OBJECTID          ID  Approximate Height (ft)  \
# count  118.000000  118.000000               118.000000
# mean    59.500000   59.500000                20.664153
# std     34.207699   34.207699                31.807566
# min      1.000000    1.000000                 1.000000
# 25%     30.250000   30.250000                 7.000000
# 50%     59.500000   59.500000                12.300000
# 75%     88.750000   88.750000                21.350000
# max    118.000000  118.000000               250.000000
#
#        Approximate Height 2 (ft)  NJSPC83 Easting (X)  NJSPC83 Northing (Y)  \
# count                 118.000000           118.000000            118.000000
# mean                   15.133305        454957.450569         766787.691911
# std                    13.876153        103181.535758          77134.500108
# min                     1.000000        317784.388000         503398.555000
# 25%                     6.000000        357433.350250         718739.527250
# 50%                    11.950000        429578.302000         789190.000000
# 75%                    18.000000        541390.147000         815008.556250
# max                    85.000000        652330.000000         892620.707000
#
#                    x              y
# count     118.000000     118.000000
# mean   454954.599897  766786.520829
# std    103176.040255   77134.156539
# min    317784.387901  503398.555107
# 25%    357433.350352  718739.527147
# 50%    429578.302108  789157.271154
# 75%    541390.147053  815008.556230
# max    652240.180930  892620.707108

# %%
wf.columns
# Out:
# Index(['OBJECTID', 'ID', 'Waterfall Name', 'Alternate Name', 'Municipality',
#        'County', 'Waterfall Type 1', 'Waterfall Type 2',
#        'Approximate Height (ft)', 'Approximate Height 2 (ft)', 'Access',
#        'Comments', 'Measurement', 'Date Measured', 'Stream Name',
#        'NJSPC83 Easting (X)', 'NJSPC83 Northing (Y)', 'GlobalID', 'x', 'y'],
#       dtype='object')

# %%
wf.shape
# Out:
# (118, 20)

# %%
wf.dtypes
# Out:
# OBJECTID                       int64
# ID                             int64
# Waterfall Name                object
# Alternate Name                object
# Municipality                  object
# County                        object
# Waterfall Type 1              object
# Waterfall Type 2              object
# Approximate Height (ft)      float64
# Approximate Height 2 (ft)    float64
# Access                        object
# Comments                      object
# Measurement                   object
# Date Measured                 object
# Stream Name                   object
# NJSPC83 Easting (X)          float64
# NJSPC83 Northing (Y)         float64
# GlobalID                      object
# x                            float64
# y                            float64
# dtype: object

# %%
wf.head()
# Out:
#    OBJECTID   ID                  Waterfall Name Alternate Name  \
# 0         1   27                 Allamuchy Falls            NaN
# 1         2  109                   Apshawa Falls            NaN
# 2         3  118    Bear Swamp Brook Falls Lower            NaN
# 3         4  117    Bear Swamp Brook Falls Upper            NaN
# 4         5  108  Bear Swamp Brook Unnamed Falls            NaN
#
#         Municipality   County Waterfall Type 1 Waterfall Type 2  \
# 0         Byram Twp.   Sussex          Cascade
# 1  West Milford Twp.  Passaic          Cascade
# 2        Mahwah Twp.   Bergen          Cascade
# 3        Mahwah Twp.   Bergen          Cascade
# 4        Mahwah Twp.   Bergen          Cascade
#
#    Approximate Height (ft)  Approximate Height 2 (ft)  Access  \
# 0                     9.68                        7.0  Public
# 1                     8.50                        8.5  Public
# 2                    15.00                       15.0  Public
# 3                    12.00                       12.0  Public
# 4                     5.30                        5.3  Public
#
#                                             Comments          Measurement  \
# 0  Located in Allamuchy Mountain State Park, this...  Trimble rangefinder
# 1  Located in Apshawa Preserve on Apshawa Creek. ...             Estimate
# 2  This falls slides over a big rounded ledge of ...    Literature search
# 3  The falls are up Bear Swamp Road, a private ro...    Literature search
# 4  The falls are up Bear Swamp Road, a private ro...  Trimble rangefinder
#
#            Date Measured               Stream Name  NJSPC83 Easting (X)  \
# 0   5/9/2019 12:00:00 AM  Jefferson Lake Tributary           426335.368
# 1  5/24/2023 12:00:00 AM             Apshawa Creek           524366.923
# 2  5/25/2023 12:00:00 AM          Bear Swamp Brook           569200.226
# 3  5/25/2023 12:00:00 AM          Bear Swamp Brook           568961.724
# 4  5/25/2023 12:00:00 AM          Bear Swamp Brook           569465.790
#
#    NJSPC83 Northing (Y)                              GlobalID              x  \
# 0            764606.933  bbbf0c68-16aa-4d81-8db9-976f1e3e905c  426335.367977
# 1            796009.519  f469f397-9cfc-4148-a768-f0ec8fc2cc12  524366.922898
# 2            817439.079  c49b73cb-3293-453f-88c3-b04da0ff5698  569200.225948
# 3            817709.178  7b7f8a6a-fea4-40c0-91b5-bf6a5560d1c4  568961.724128
# 4            817181.169  86b3ee23-1f31-4d85-a28e-2ba6e3b12f62  569465.790049
#
#                y
# 0  764606.932952
# 1  796009.519097
# 2  817439.078928
# 3  817709.178125
# 4  817181.169011

# %%
wf.tail()
# Out:
#      OBJECTID   ID                        Waterfall Name Alternate Name  \
# 113       114   99  Van Campens Glen Unnamed Waterfall 2            NaN
# 114       115   24                   Wanaque River Falls            NaN
# 115       116   98                   Weldon Quarry Falls            NaN
# 116       117  100                        Wetumpka Falls            NaN
# 117       118   25                        Wyanokie Falls            NaN
#
#              Municipality   County      Waterfall Type 1 Waterfall Type 2  \
# 113         Hardwick Twp.   Warren                Plunge
# 114     West Milford Twp.  Passaic                 Chute
# 115     Hopatcong Borough   Sussex               Cascade
# 116      Watchung Borough    Union               Cascade
# 117  Bloomingdale Borough  Passaic  Multi-step waterfall          Cascade
#
#      Approximate Height (ft)  Approximate Height 2 (ft)   Access  \
# 113                    11.00                      11.00   Public
# 114                     7.15                       7.15   Public
# 115                    10.20                       4.00  Private
# 116                    20.00                       9.00   Public
# 117                    31.50                      15.00   Public
#
#                                               Comments          Measurement  \
# 113  A small waterfall a few hundred feet upstream ...  Trimble rangefinder
# 114  Small waterfall located on the Wanaque River a...  Trimble rangefinder
# 115  A small cascade next to the Weldon Quarry on p...  Trimble rangefinder
# 116  Located along Somers Ave. on Stony Brook acros...  Trimble rangefinder
# 117  Two tier falls located along Blue Mine Brook. ...  Trimble rangefinder
#
#               Date Measured             Stream Name  NJSPC83 Easting (X)  \
# 113   6/25/2019 12:00:00 AM        Vancampens Brook           357357.892
# 114   4/14/2022 12:00:00 AM           Wanaque River           542914.892
# 115  11/20/2019 12:00:00 AM  Weldon Brook Tributary           458973.640
# 116   9/13/2017 12:00:00 AM             Stony Brook           506789.027
# 117   9/13/2017 12:00:00 AM         Blue Mine Brook           541848.548
#
#      NJSPC83 Northing (Y)                              GlobalID  \
# 113            812291.224  6add5441-80d1-4048-b009-d0d87a08b9e8
# 114            848610.479  03221fce-47bc-45f5-95fc-8bae87889a9c
# 115            785094.430  2d124c38-199e-4529-adbe-3d46d8e5516e
# 116            655884.180  7c7b98ee-1455-4854-b30d-6aa1c215393c
# 117            812984.077  a2078aa6-ee1d-4972-8baf-b6fdc317ae6a
#
#                  x              y
# 113  357357.892087  812291.224066
# 114  542914.892035  848610.478855
# 115  458973.639971  785094.430035
# 116  506789.026951  655884.179925
# 117  541848.548039  812984.077011

# %%
wf.sample(5)
# Out:
#      OBJECTID  ID                            Waterfall Name  \
# 21         22  41                Clinton Falls (High Falls)
# 42         43  83  Flat Brook Tributary Unnamed Waterfall 3
# 104       105  19                            Tumble Falls 3
# 18         19  38                            Cataract Falls
# 43         44  84  Flat Brook Tributary Unnamed Waterfall 4
#
#                 Alternate Name       Municipality     County Waterfall Type 1  \
# 21   High Falls, Janetta Falls  West Milford Twp.    Passaic           Plunge
# 42                         NaN       Walpack Twp.     Sussex          Cascade
# 104                        NaN      Kingwood Twp.  Hunterdon          Cascade
# 18                The Cataract    Washington Twp.     Morris         Cataract
# 43                         NaN       Walpack Twp.     Sussex          Cascade
#
#     Waterfall Type 2  Approximate Height (ft)  Approximate Height 2 (ft)  \
# 21             Chute                     20.0                       20.0
# 42                                        4.0                        4.0
# 104                                      30.0                       30.0
# 18           Cascade                     51.5                       44.3
# 43                                        4.0                        4.0
#
#       Access                                           Comments  \
# 21    Public  The falls is located under a stone bridge on C...
# 42    Public  Small waterfall on west side of Kittattinny Mo...
# 104  Private  Located along Rt. 29. Located 200 feet back fr...
# 18    Public  The top section of the falls is very tall. Loc...
# 43    Public  Small waterfall on west side of Kittattinny Mo...
#
#              Measurement          Date Measured  \
# 21   Trimble rangefinder  3/14/2019 12:00:00 AM
# 42              Estimate   6/7/2023 12:00:00 AM
# 104             Estimate  9/27/2018 12:00:00 AM
# 18   Trimble rangefinder  3/20/2019 12:00:00 AM
# 43              Estimate   6/7/2023 12:00:00 AM
#
#                             Stream Name  NJSPC83 Easting (X)  \
# 21                        Clinton Brook           505897.479
# 42                 Flat Brook Tributary           379689.652
# 104            Delaware River Tributary           335427.610
# 18   Schooleys Mountain Brook Tributary           405452.434
# 43                 Flat Brook Tributary           379429.991
#
#      NJSPC83 Northing (Y)                              GlobalID  \
# 21             815432.175  4abf0189-12ea-4801-ac03-3278091f1ee2
# 42             832340.396  e1f806eb-dd3f-41a9-8256-262dc999381e
# 104            586611.410  646f14e8-e9c1-41f7-9301-457ea78fb173
# 18             721653.824  b5134987-cf98-44b7-9caf-f60ddc7b239a
# 43             832653.125  036f3b4e-cf7b-4c9f-a1a3-1af1750a0445
#
#                  x              y
# 21   505897.478866  815432.175133
# 42   379689.651885  832340.395910
# 104  335427.610160  586611.410007
# 18   405452.434021  721653.823976
# 43   379429.990987  832653.124943

# %%
wf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   OBJECTID                   118 non-null    int64
#  1   ID                         118 non-null    int64
#  2   Waterfall Name             118 non-null    object
#  3   Alternate Name             16 non-null     object
#  4   Municipality               118 non-null    object
#  5   County                     118 non-null    object
#  6   Waterfall Type 1           118 non-null    object
#  7   Waterfall Type 2           114 non-null    object
#  8   Approximate Height (ft)    118 non-null    float64
#  9   Approximate Height 2 (ft)  118 non-null    float64
#  10  Access                     118 non-null    object
#  11  Comments                   118 non-null    object
#  12  Measurement                118 non-null    object
#  13  Date Measured              118 non-null    object
#  14  Stream Name                118 non-null    object
#  15  NJSPC83 Easting (X)        118 non-null    float64
#  16  NJSPC83 Northing (Y)       118 non-null    float64
#  17  GlobalID                   118 non-null    object
#  18  x                          118 non-null    float64
#  19  y                          118 non-null    float64
# dtypes: float64(6), int64(2), object(12)
# memory usage: 18.6+ KB

# %%
wf.sort_values('Approximate Height (ft)', ascending = False)
# Out:
#      OBJECTID  ID                                    Waterfall Name  \
# 45         46  89                                  Greenbrook Falls
# 62         63  91                                  Lost Brook Falls
# 13         14  33                                  Buttermilk Falls
# 44         45  85                        Great Falls of the Passaic
# 66         67  92                Old Mine Road Unnamed Waterfall  1
# ..        ...  ..                                               ...
# 38         39  52  Dunnfield Creek Natural Area Unnamed Waterfall 8
# 75         76  74                        Rinehart Brook Falls Lower
# 58         59  63                                    Little Falls 2
# 59         60  64                                    Little Falls 3
# 100       101  15                                     Trenton Falls
#
#                 Alternate Name     Municipality   County  \
# 45                         NaN   Alpine Borough   Bergen
# 62                         NaN  Tenafly Borough   Bergen
# 13                         NaN     Walpack Twp.   Sussex
# 44   Totowa Falls, Great Falls         Paterson  Passaic
# 66                         NaN    Hardwick Twp.   Sussex
# ..                         ...              ...      ...
# 38                         NaN    Hardwick Twp.   Warren
# 75                         NaN     Chester Twp.   Morris
# 58                         NaN     Little Falls  Passaic
# 59                         NaN     Little Falls  Passaic
# 100      Falls of the Delaware          Trenton   Mercer
#
#          Waterfall Type 1      Waterfall Type 2  Approximate Height (ft)  \
# 45                 Plunge               Cascade                   250.00
# 62                Cascade                                         200.00
# 13   Multi-step waterfall               Cascade                   130.00
# 44        Block Waterfall                   NaN                    77.00
# 66                Cascade  Multi-step waterfall                    60.90
# ..                    ...                   ...                      ...
# 38                Cascade                                           3.79
# 75                Cascade                                           3.71
# 58                Cascade                                           2.00
# 59                Cascade                                           1.32
# 100               Cascade                                           1.00
#
#      Approximate Height 2 (ft)  Access  \
# 45                       85.00  Public
# 62                       75.00  Public
# 13                       30.00  Public
# 44                       77.00  Public
# 66                       17.70  Public
# ..                         ...     ...
# 38                        3.79  Public
# 75                        3.71  Public
# 58                        2.00  Public
# 59                        1.32  Public
# 100                       1.00  Public
#
#                                               Comments          Measurement  \
# 45   The estimated 250-foot Greenbrook Falls is New...    Literature search
# 62   Second largest falls in New Jersey. It cascade...             Estimate
# 13                  The third tallest waterfall in NJ.  Trimble rangefinder
# 44   Small waterfall on west side of Kittattinny Mo...    Literature search
# 66   Located along Old Mine Road. A multi-tiered st...  Trimble rangefinder
# ..                                                 ...                  ...
# 38   Small cascade with unknown name at the junctio...             Estimate
# 75                      Small falls on Rinehart Brook.  Trimble rangefinder
# 58   Downstream of the Little Falls closest to the ...  Trimble rangefinder
# 59   Downstream of the Little Falls closest to the ...  Trimble rangefinder
# 100  GPS location taken from PA side of Delaware. N...    Literature search
#
#               Date Measured               Stream Name  NJSPC83 Easting (X)  \
# 45     5/3/2018 12:00:00 AM               Green Brook           650098.647
# 62     5/3/2018 12:00:00 AM                Lost Brook           648938.790
# 13    7/26/2017 12:00:00 AM      Flat Brook Tributary           384958.815
# 44     8/5/2017 12:00:00 AM             Passaic River           580237.919
# 66    3/28/2019 12:00:00 AM  Delaware River Tributary           326967.038
# ..                      ...                       ...                  ...
# 38   10/30/2019 12:00:00 AM           Dunnfield Creek           320063.000
# 75    7/30/2019 12:00:00 AM            Rinehart Brook           427924.405
# 58    7/11/2019 12:00:00 AM   Passaic River Tributary           566023.792
# 59    7/11/2019 12:00:00 AM   Passaic River Tributary           566151.223
# 100   7/12/2017 12:00:00 AM            Delaware River           415866.814
#
#      NJSPC83 Northing (Y)                              GlobalID  \
# 45             760552.154  30d91fd4-9799-4f6b-ba34-31e2cfe94b47
# 62             757636.782  35416096-aee8-4e94-914e-e6fdba7f9f88
# 13             839348.272  abf6cbe5-b13d-44bd-bb1d-a18d49eea72d
# 44             758669.410  4b355710-705f-4eaf-bbff-6343e3cb0afe
# 66             791392.512  4e30cb4e-95de-4dc2-bef6-ae534a07c472
# ..                    ...                                   ...
# 38             780956.000  b61deb38-924c-4e70-b2f2-5ea02628fc4a
# 75             696095.976  99cf32d7-1716-44e6-8e08-84c04d35803a
# 58             746895.822  020571ba-39b9-4a33-b06b-54773d9e92ef
# 59             746818.238  397313c7-33d4-44b7-b337-92ce91397b62
# 100            503398.555  21f19c70-318e-45b7-9dea-cc6fef0474e9
#
#                  x              y
# 45   650098.647156  760552.153988
# 62   648938.789895  757636.781866
# 13   384958.814904  839348.271986
# 44   580237.919095  758669.410050
# 66   326967.037843  791392.511927
# ..             ...            ...
# 38   320063.000142  780955.999991
# 75   427924.405153  696095.976142
# 58   566023.792012  746895.822049
# 59   566151.222859  746818.237886
# 100  415866.814111  503398.555107
#
# [118 rows x 20 columns]

# %%
wf[wf['Waterfall Type 1' or 'Waterfall Type 2'] == 'Horsetail']
# Out:
#     OBJECTID  ID    Waterfall Name Alternate Name      Municipality    County  \
# 15        16  35  Buttermilk Falls            NaN  Bridgewater Twp.  Somerset
#
#    Waterfall Type 1 Waterfall Type 2  Approximate Height (ft)  \
# 15        Horsetail                                      27.2
#
#     Approximate Height 2 (ft)  Access  \
# 15                       27.2  Public
#
#                                              Comments          Measurement  \
# 15  Located in Washington Valley Park. At the end ...  Trimble rangefinder
#
#             Date Measured      Stream Name  NJSPC83 Easting (X)  \
# 15  3/14/2019 12:00:00 AM  MacMillan Brook           476263.477
#
#     NJSPC83 Northing (Y)                              GlobalID             x  \
# 15            638324.458  d84d1f7c-b771-416c-9d0b-2789e92ffef6  476263.47711
#
#                 y
# 15  638324.458155

# %%
wf['Waterfall Type 1' or 'Waterfall Type 2'].unique()
# Out:
# array(['Cascade', 'Multi-step waterfall', 'Plunge', 'Horsetail',
#        'Cataract', 'Fantail', 'Chute', 'Block Waterfall'], dtype=object)

# %%
wf['Waterfall Type 1' or 'Waterfall Type 2'].value_counts()
# Out:
# Cascade                 93
# Multi-step waterfall     8
# Chute                    7
# Plunge                   4
# Cataract                 2
# Fantail                  2
# Horsetail                1
# Block Waterfall          1
# Name: Waterfall Type 1, dtype: int64

# %%
wf_morris = wf[wf['County'] == 'Morris']
wf_morris['Municipality'].value_counts()
# Out:
# Chester Twp.       8
# Washington Twp.    7
# Mendham Twp.       2
# Boonton            1
# Mine Hill Twp.     1
# Montville Twp.     1
# Name: Municipality, dtype: int64
