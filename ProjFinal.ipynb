# %% [markdown]
# # Final Project: Milestone 2
# ### Elizabeth Trunk, CMP 262
# ### April 15, 2026

# %% [markdown]
# In this project, I will analyze waterfalls in New Jersey.

# %% [markdown]
# ### Set Up

# %%
import pandas as pd

# %%
df = "waterfalls.csv"
wf = pd.read_csv(df)

# %% [markdown]
# ### Initial Exploratory Analysis

# %%
wf
# Out:
#      OBJECTID   ID                        Waterfall Name Alternate Name  \
# 0           1   27                       Allamuchy Falls            NaN
# 1           2  109                         Apshawa Falls            NaN
# 2           3  118          Bear Swamp Brook Falls Lower            NaN
# 3           4  117          Bear Swamp Brook Falls Upper            NaN
# 4           5  108        Bear Swamp Brook Unnamed Falls            NaN
# ..        ...  ...                                   ...            ...
# 113       114   99  Van Campens Glen Unnamed Waterfall 2            NaN
# 114       115   24                   Wanaque River Falls            NaN
# 115       116   98                   Weldon Quarry Falls            NaN
# 116       117  100                        Wetumpka Falls            NaN
# 117       118   25                        Wyanokie Falls            NaN
#
#              Municipality   County      Waterfall Type 1 Waterfall Type 2  \
# 0              Byram Twp.   Sussex               Cascade
# 1       West Milford Twp.  Passaic               Cascade
# 2             Mahwah Twp.   Bergen               Cascade
# 3             Mahwah Twp.   Bergen               Cascade
# 4             Mahwah Twp.   Bergen               Cascade
# ..                    ...      ...                   ...              ...
# 113         Hardwick Twp.   Warren                Plunge
# 114     West Milford Twp.  Passaic                 Chute
# 115     Hopatcong Borough   Sussex               Cascade
# 116      Watchung Borough    Union               Cascade
# 117  Bloomingdale Borough  Passaic  Multi-step waterfall          Cascade
#
#      Approximate Height (ft)  Approximate Height 2 (ft)   Access  \
# 0                       9.68                       7.00   Public
# 1                       8.50                       8.50   Public
# 2                      15.00                      15.00   Public
# 3                      12.00                      12.00   Public
# 4                       5.30                       5.30   Public
# ..                       ...                        ...      ...
# 113                    11.00                      11.00   Public
# 114                     7.15                       7.15   Public
# 115                    10.20                       4.00  Private
# 116                    20.00                       9.00   Public
# 117                    31.50                      15.00   Public
#
#                                               Comments          Measurement  \
# 0    Located in Allamuchy Mountain State Park, this...  Trimble rangefinder
# 1    Located in Apshawa Preserve on Apshawa Creek. ...             Estimate
# 2    This falls slides over a big rounded ledge of ...    Literature search
# 3    The falls are up Bear Swamp Road, a private ro...    Literature search
# 4    The falls are up Bear Swamp Road, a private ro...  Trimble rangefinder
# ..                                                 ...                  ...
# 113  A small waterfall a few hundred feet upstream ...  Trimble rangefinder
# 114  Small waterfall located on the Wanaque River a...  Trimble rangefinder
# 115  A small cascade next to the Weldon Quarry on p...  Trimble rangefinder
# 116  Located along Somers Ave. on Stony Brook acros...  Trimble rangefinder
# 117  Two tier falls located along Blue Mine Brook. ...  Trimble rangefinder
#
#               Date Measured               Stream Name  NJSPC83 Easting (X)  \
# 0      5/9/2019 12:00:00 AM  Jefferson Lake Tributary           426335.368
# 1     5/24/2023 12:00:00 AM             Apshawa Creek           524366.923
# 2     5/25/2023 12:00:00 AM          Bear Swamp Brook           569200.226
# 3     5/25/2023 12:00:00 AM          Bear Swamp Brook           568961.724
# 4     5/25/2023 12:00:00 AM          Bear Swamp Brook           569465.790
# ..                      ...                       ...                  ...
# 113   6/25/2019 12:00:00 AM          Vancampens Brook           357357.892
# 114   4/14/2022 12:00:00 AM             Wanaque River           542914.892
# 115  11/20/2019 12:00:00 AM    Weldon Brook Tributary           458973.640
# 116   9/13/2017 12:00:00 AM               Stony Brook           506789.027
# 117   9/13/2017 12:00:00 AM           Blue Mine Brook           541848.548
#
#      NJSPC83 Northing (Y)                              GlobalID  \
# 0              764606.933  bbbf0c68-16aa-4d81-8db9-976f1e3e905c
# 1              796009.519  f469f397-9cfc-4148-a768-f0ec8fc2cc12
# 2              817439.079  c49b73cb-3293-453f-88c3-b04da0ff5698
# 3              817709.178  7b7f8a6a-fea4-40c0-91b5-bf6a5560d1c4
# 4              817181.169  86b3ee23-1f31-4d85-a28e-2ba6e3b12f62
# ..                    ...                                   ...
# 113            812291.224  6add5441-80d1-4048-b009-d0d87a08b9e8
# 114            848610.479  03221fce-47bc-45f5-95fc-8bae87889a9c
# 115            785094.430  2d124c38-199e-4529-adbe-3d46d8e5516e
# 116            655884.180  7c7b98ee-1455-4854-b30d-6aa1c215393c
# 117            812984.077  a2078aa6-ee1d-4972-8baf-b6fdc317ae6a
#
#                  x              y
# 0    426335.367977  764606.932952
# 1    524366.922898  796009.519097
# 2    569200.225948  817439.078928
# 3    568961.724128  817709.178125
# 4    569465.790049  817181.169011
# ..             ...            ...
# 113  357357.892087  812291.224066
# 114  542914.892035  848610.478855
# 115  458973.639971  785094.430035
# 116  506789.026951  655884.179925
# 117  541848.548039  812984.077011
#
# [118 rows x 20 columns]

# %%
wf.describe()

# %%
wf.columns

# %%
wf.shape

# %%
wf.dtypes

# %%
wf.head()

# %%
wf.tail()

# %%
wf.sample(5)

# %%
wf.info()

# %%
wf.sort_values('Approximate Height (ft)', ascending = False)

# %%
wf[wf['Waterfall Type 1' or 'Waterfall Type 2'] == 'Horsetail']

# %%
wf['Waterfall Type 1' or 'Waterfall Type 2'].unique()

# %%
wf['Waterfall Type 1' or 'Waterfall Type 2'].value_counts()

# %%
wf_morris = wf[wf['County'] == 'Morris']
wf_morris['Municipality'].value_counts()

# %% [markdown]
# ### Cleaning

# %%
wf.columns
# Out:
# Index(['OBJECTID', 'ID', 'Waterfall Name', 'Alternate Name', 'Municipality',
#        'County', 'Waterfall Type 1', 'Waterfall Type 2',
#        'Approximate Height (ft)', 'Approximate Height 2 (ft)', 'Access',
#        'Comments', 'Measurement', 'Date Measured', 'Stream Name',
#        'NJSPC83 Easting (X)', 'NJSPC83 Northing (Y)', 'GlobalID', 'x', 'y'],
#       dtype='object')

# %%
wf.drop(columns = ['Comments',
